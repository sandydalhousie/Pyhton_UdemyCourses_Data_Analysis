# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
data = pd.read_csv("C:/Users/SANDY/Desktop/DATA ANALYSIS FILES - JULY 2024/PROJECT 14 - USING PYTHON [CASE STUDY 05] [UDEMY COURSE DETAILS]/udemy_courses.csv", parse_dates=["published_timestamp"])

# %%
df = pd.DataFrame(data)
df.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %% [markdown]
# 1. Display Top 10 Rows of The Dataset

# %%
df.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %% [markdown]
# 2. Check Last 5 Rows of The Dataset

# %%
df.tail(5)
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %% [markdown]
# 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
df.shape
# Out:
# (3678, 12)

# %% [markdown]
# 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %% [markdown]
# 5. Check Null Values In The Dataset

# %%
df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %% [markdown]
# PLOTTING NULL VALUES HEATMAP

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# 6. Check For Duplicate Data and Drop Them

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 7. Find Out Number of Courses Per Subjects

# %%
df.columns
df.groupby("subject").agg({"course_title":"count"})
# Out:
#                      course_title
# subject
# Business Finance             1191
# Graphic Design                602
# Musical Instruments           680
# Web Development              1199

# %% [markdown]
# PLOTTING NO OF COURSES

# %%
sns.countplot(df["subject"],palette="GnBu")
plt.xlabel("No of courses per subject")
plt.ylabel("SUBJECTS")
plt.show()
# Out:
# C:\Users\SANDY\AppData\Local\Temp\ipykernel_7948\1617856815.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df["subject"],palette="GnBu")

# %% [markdown]
# 8. For Which Levels, Udemy Courses Providing The Courses

# %%
df.head(2)
df.level.unique()
df["level"].value_counts()
# Out:
# level
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %% [markdown]
# PLOTTING THE UDEMY LEVELS COUNT

# %%
sns.countplot(df["level"], palette="viridis")
plt.xlabel("No of courses with these levels")
plt.ylabel("LEVELS")
plt.show()
# Out:
# C:\Users\SANDY\AppData\Local\Temp\ipykernel_7948\69762947.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df["level"], palette="viridis")

# %% [markdown]
# 9. Display The Count of Paid and Free Courses

# %%
df.columns
df1 = df["is_paid"].value_counts()

# %% [markdown]
# 10. Which Course Has More Lectures (Free or Paid)?

# %%
df.head(2)
df.groupby("is_paid").agg({"num_lectures":"mean"})
# Out:
#          num_lectures
# is_paid
# False       21.416129
# True        41.866746

# %% [markdown]
# 11. Which Courses Have A Higher Number of Subscribers Free or Paid?

# %%
df.head(2)
df.groupby("is_paid").agg({"num_subscribers":"mean"})
# Out:
#          num_subscribers
# is_paid
# False       11533.951613
# True         2421.270077

# %%
sns.barplot(data=df, x="is_paid", y="num_subscribers", palette="GnBu")
plt.show()
# Out:
# C:\Users\SANDY\AppData\Local\Temp\ipykernel_7948\881542955.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="is_paid", y="num_subscribers", palette="GnBu")

# %% [markdown]
# 12. Which Level Has The Highest Number of Subscribers?

# %%
df.head(2)
df.groupby("level").agg({"num_subscribers":"mean"})
#df.groupby("level").agg({"num_subscribers":"mean"}).max()
# Out:
#                     num_subscribers
# level
# All Levels              3569.761558
# Beginner Level          3195.459779
# Expert Level             865.448276
# Intermediate Level      1762.482185

# %%
sns.barplot(data=df, x="level", y="num_subscribers", palette="hot")
plt.xticks(rotation=60)
plt.show()
# Out:
# C:\Users\SANDY\AppData\Local\Temp\ipykernel_7948\3122819307.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="level", y="num_subscribers", palette="hot")

# %% [markdown]
# 13. Find Most Popular Course Title

# %%
df.head(2)
df[df["num_subscribers"].max() == df["num_subscribers"]]
#df[df["num_subscribers"].max() == df["num_subscribers"]]["course_title"]
# Out:
#       course_id                          course_title  \
# 2827      41295  Learn HTML5 Programming From Scratch
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 2827           268923         8629            45  All Levels
#
#       content_duration       published_timestamp          subject
# 2827              10.5 2013-02-14 07:03:41+00:00  Web Development

# %% [markdown]
# 14. Display 10 Most Popular Courses As Per Number of Subscribers

# %%
df.head(2)
#df.groupby("course_title").agg({"num_subscribers":"mean"}).head(10)
top_10 = df.sort_values(by="num_subscribers", ascending=False).head(10)
top_10
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# 1896      19421              Free Beginner Electric Guitar Lessons
# 2589     473160  Web Design for Web Developers: Build Beautiful...
# 2619      94430             Learn Javascript & JQuery From Scratch
# 3289     130064  Practical PHP: Master the Basics and Code Dyna...
# 3247     364426          JavaScript: Understanding the Weird Parts
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# 3032  https://www.udemy.com/coding-for-entrepreneurs...    False      0
# ...

# %%
sns.barplot(data=top_10, x="num_subscribers", y="course_title", palette="GnBu")
plt.show()
# Out:
# C:\Users\SANDY\AppData\Local\Temp\ipykernel_7948\2179627414.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_10, x="num_subscribers", y="course_title", palette="GnBu")

# %% [markdown]
# 15. Find The Course Which Is Having The Highest Number of Reviews.

# %%
df.head(2)
#df.sort_values(by="num_reviews", ascending=False)
#df[df["num_reviews"].max() == df["num_reviews"]]
df3 = df.groupby("subject").agg({"num_reviews":"mean"}).sort_values(by="num_reviews", ascending=False)
df3
# Out:
#                      num_reviews
# subject
# Web Development       358.354167
# Business Finance       63.516318
# Graphic Design         61.475954
# Musical Instruments    46.652941

# %%
sns.barplot(data=df, x=df["subject"], y=df["num_reviews"], palette="GnBu")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SANDY\AppData\Local\Temp\ipykernel_7948\271631590.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x=df["subject"], y=df["num_reviews"], palette="GnBu")

# %% [markdown]
# 16. Does Price Affect the Number of Reviews?

# %%
df.head(2)
plt.figure(figsize=(15,6))
sns.scatterplot(data=df, x="price", y="num_reviews")
plt.show()
#df.corr(df["num_reviews"],df["price"])

# %% [markdown]
# TRYING TO FIND CORRELATION BETWEEN PRICE AND NO OF REVIEWS USING df.corr() FUNCTION

# %%
df4 = df.copy()
df4.columns
df4.drop(columns=['course_id', 'course_title', 'url', 'is_paid',
       'num_subscribers', 'num_lectures', 'level',
       'content_duration', 'published_timestamp', 'subject'], axis=1, inplace=True)
df4.corr(min_periods=3)
# Out:
#                 price  num_reviews
# price        1.000000     0.113568
# num_reviews  0.113568     1.000000

# %% [markdown]
# 17. Find Total Number of Courses Related To Python

# %%
df.head(2)
len(df[df["course_title"].str.contains("python", case=False)])
#df["course_title"].str.contains("python", case=False).value_counts()
# Out:
# 29

# %% [markdown]
# 18. Display 10 Most Popular Python Courses As Per Number of Subscribers

# %%
df.head(2)
python = df[df["course_title"].str.contains("python", case=False)].sort_values(by="num_subscribers", ascending=False).head(10)
python
# Out:
#       course_id                                       course_title  \
# 2497      16646                        Web Programming with Python
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# 2528     391546        Learn Python and Django: Payment Processing
# 3200     822444  Python and Django Full Stack Web Developer Boo...
# 3507     394832  Fun and creative web engineering with Python a...
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 3138     631128  Complete Python Web Course: Build 8 Python Web...
# 3197      76052  Try Django 1.9 | Build a Blog and Learn Python...
# 2681     477702  Python for Beginners: Python Programming Langu...
# 3203     970600                    REST APIs with Flask and Python
#
#                                                     url  is_paid  price  \
# 2497  https://www.udemy.com/web-programming-with-pyt...     True     50
# 2570    https://www.udemy.com/coding-for-entrepreneurs/     True    195
# ...

# %%
sns.barplot(data=python, y="course_title", x="num_subscribers", palette="GnBu")
plt.show()
# Out:
# C:\Users\SANDY\AppData\Local\Temp\ipykernel_7948\1775027959.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=python, y="course_title", x="num_subscribers", palette="GnBu")

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'Year'],
#       dtype='object')

# %% [markdown]
# 19. In Which Year The Highest Number of Courses Were Posted?

# %%
df.head(2)
df["published_timestamp"] = pd.to_datetime(df["published_timestamp"])
df["Year"] = df["published_timestamp"].dt.year
df.head(2)
df5 = df.groupby("Year").agg({"course_title":"count"}).sort_values(by="course_title", ascending=False)
df5
# Out:
#       course_title
# Year
# 2016          1206
# 2015          1014
# 2017           715
# 2014           491
# 2013           202
# 2012            45
# 2011             5

# %%
sns.countplot(data=df, x=df["Year"], palette="GnBu")
plt.show()
# Out:
# C:\Users\SANDY\AppData\Local\Temp\ipykernel_7948\1398040902.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=df["Year"], palette="GnBu")

# %% [markdown]
# 20. Display Category-Wise Count of Posted Subjects [Year Wise]

# %%
df.head(2)
df.groupby(["Year", "subject"]).agg({"subject":"count"})
# Out:
#                           subject
# Year subject
# 2011 Web Development            5
# 2012 Business Finance           6
#      Graphic Design            10
#      Musical Instruments       10
#      Web Development           19
# 2013 Business Finance          84
#      Graphic Design            23
#      Musical Instruments       39
#      Web Development           56
# 2014 Business Finance         192
#      Graphic Design            66
#      Musical Instruments      120
#      Web Development          113
# 2015 Business Finance         339
#      Graphic Design           168
#      Musical Instruments      171
#      Web Development          336
# 2016 Business Finance         349
#      Graphic Design           181
#      Musical Instruments      228
#      Web Development          448
# 2017 Business Finance         225
#      Graphic Design           155
#      Musical Instruments      112
#      Web Development          223
